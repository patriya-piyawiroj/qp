# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from scipy.signal.windows import gaussian
from scipy.ndimage import convolve1d
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

def print_correlation():
    features = ['Fed Rate', 'Volume', 'CPI', 'CPI_pct', 'DXY', 'SPX', 't']
    columns = []
    for x in features:
        row = []
        for y in features:
            correlation = raw[x].corr(raw[y])
            row.append(correlation)
        columns.append(row)
    df = pd.DataFrame(columns, columns=[f'{j}' for j in features], index=[f'{i}' for i in features])
    print(df)
    
pd.set_option('display.expand_frame_repr', False) 
raw = pd.read_excel('raw.xlsx')
raw['CPI_pct'] = raw['CPI'].pct_change() * 100
print_correlation()
# Out:
#           Fed Rate    Volume       CPI   CPI_pct       DXY       SPX         t      Gold
# Fed Rate  1.000000 -0.724780 -0.759364  0.016192  0.537550 -0.541173  0.007440 -0.637201
# Volume   -0.724780  1.000000  0.842348 -0.020974 -0.377746  0.684441 -0.028460  0.805867
# CPI      -0.759364  0.842348  1.000000 -0.007325 -0.376388  0.914550 -0.008636  0.873799
# CPI_pct   0.016192 -0.020974 -0.007325  1.000000  0.004331  0.006193 -0.181981 -0.000386
# DXY       0.537550 -0.377746 -0.376388  0.004331  1.000000 -0.130531 -0.004679 -0.294652
# SPX      -0.541173  0.684441  0.914550  0.006193 -0.130531  1.000000  0.017011  0.826003
# t         0.007440 -0.028460 -0.008636 -0.181981 -0.004679  0.017011  1.000000  0.007818
# Gold     -0.637201  0.805867  0.873799 -0.000386 -0.294652  0.826003  0.007818  1.000000

# %%
# Perform inflation adjustment
raw['Gold'] = raw['Gold']/raw['CPI']
raw['SPX'] = raw['SPX']/raw['CPI']

plt.plot(raw['Date'], raw['Gold'], label='Gold')
plt.plot(raw['Date'], raw['SPX'], label='SPX')

print_correlation()
# Out:
#           Fed Rate    Volume       CPI   CPI_pct       DXY       SPX         t      Gold
# Fed Rate  1.000000 -0.724780 -0.759364  0.016192  0.537550 -0.443415  0.007440  0.173431
# Volume   -0.724780  1.000000  0.842348 -0.020974 -0.377746  0.463756 -0.028460  0.069197
# CPI      -0.759364  0.842348  1.000000 -0.007325 -0.376388  0.739600 -0.008636 -0.139253
# CPI_pct   0.016192 -0.020974 -0.007325  1.000000  0.004331 -0.000778 -0.181981  0.014207
# DXY       0.537550 -0.377746 -0.376388  0.004331  1.000000 -0.096111 -0.004679  0.161814
# SPX      -0.443415  0.463756  0.739600 -0.000778 -0.096111  1.000000  0.045306 -0.400635
# t         0.007440 -0.028460 -0.008636 -0.181981 -0.004679  0.045306  1.000000  0.026240
# Gold      0.173431  0.069197 -0.139253  0.014207  0.161814 -0.400635  0.026240  1.000000

# %%
# Plot time

plt.plot(raw['Date'], raw['Gold']/1000, label='Gold')
plt.plot(raw['Date'], raw['CPI_pct'], label='CPI')
plt.plot(raw['Date'], raw['DXY']/100, label='DXY')

# %%
raw.to_excel('decorrelated.xlsx')
